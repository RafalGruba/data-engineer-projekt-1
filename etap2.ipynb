# %%
import pandas as pd

df = pd.read_csv('players_data-2025_2026.csv')
df.columns = df.columns.str.lower()

df.shape
# Out:
# (2839, 102)

# %%
df.head()
# Out:
#    rk               player   nation    pos              squad  \
# 0   1     Brenden Aaronson   us USA  MF,FW       Leeds United
# 1   2         Jerome Abbey  eng ENG     MF             Wolves
# 2   3          Zach Abbott  eng ENG     DF  Nottingham Forest
# 3   4  Jones El-Abdellaoui   ma MAR  MF,FW         Celta Vigo
# 4   5        Himad Abdelli   dz ALG     MF          Marseille
#
#                  comp   age    born  mp  starts  ...  crdy_stats_misc  \
# 0  eng Premier League  24.0  2000.0  37      30  ...                3
# 1  eng Premier League  15.0  2009.0   1       0  ...                0
# 2  eng Premier League  19.0  2006.0   3       2  ...                0
# 3          es La Liga  19.0  2006.0  22       4  ...                0
# 4          fr Ligue 1  25.0  1999.0   8       1  ...                1
#
#    crdr_stats_misc  2crdy  fls  fld  off  crs  int  tklw  og
# 0                0      0   20   51    5   37   17    27   0
# 1                0      0    0    0    1    0    1     0   0
# 2                0      0    3    1    0    3    2     4   0
# 3                0      0    7    3    2   30    3     3   0
# 4                0      0    3    0    0    1    2     1   0
#
# [5 rows x 102 columns]

# %%
df.dtypes.age
# Out:
# dtype('float64')

# %%
df.dtypes.gls
# Out:
# dtype('int64')

# %%
df['age'].isnull().sum()
# Out:
# np.int64(2)

# %%
df[df['age'].isnull()]
# Out:
#         rk         player nation pos     squad        comp  age  born  mp  \
# 2004  2005  Luis Orejuela    NaN  DF  Mallorca  es La Liga  NaN   NaN   1
# 2630  2631     Yael Trepy    NaN  FW  Cagliari  it Serie A  NaN   NaN   8
#
#       starts  ...  crdy_stats_misc  crdr_stats_misc  2crdy  fls  fld  off  \
# 2004       1  ...                0                0      0    1    4    0
# 2630       0  ...                0                0      0    1    2    2
#
#       crs  int  tklw  og
# 2004    2    1     0   0
# 2630    7    0     1   0
#
# [2 rows x 102 columns]

# %%
df_clean = df.dropna(subset=['age'])

# %%
df_clean.shape
# Out:
# (2837, 102)

# %%
df_clean['age'].isnull().sum()
# Out:
# np.int64(0)
